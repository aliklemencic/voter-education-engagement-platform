# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from itertools import combinations
import seaborn as sns

ratings = pd.read_csv('ratings.csv', sep='\t', encoding='latin-1', usecols=['user_id', 'movie_id', 'rating'])
users = pd.read_csv('users.csv', sep='\t', encoding='latin-1', usecols=['user_id', 'gender', 'zipcode', 'age_desc', 'occ_desc'])
movies = pd.read_csv('movies.csv', sep='\t', encoding='latin-1', usecols=['movie_id', 'title', 'genres'])

# %%
def weighted_average_score(df, k=0.8):
    n_views = df.groupby('movie_id', sort=False).movie_id.count()
    ratings = df.groupby('movie_id', sort=False).rating.mean()
    scores = ((1-k)*(n_views/n_views.max()) + 
              k*(ratings/ratings.max())).to_numpy().argsort()[::-1]
    df_deduped = df.groupby('movie_id', sort=False).agg({'title':'first', 
                                                         'genres':'first', 
                                                         'rating':'mean'})
    return df_deduped.assign(views=n_views).iloc[scores]

# %%
df = movies.merge(ratings).merge(users)
weighted_average_score(df).head(10)
# Out:
#                                                       title  \
# movie_id
# 2858                                 American Beauty (1999)
# 260               Star Wars: Episode IV - A New Hope (1977)
# 1196      Star Wars: Episode V - The Empire Strikes Back...
# 527                                 Schindler's List (1993)
# 2028                             Saving Private Ryan (1998)
# 1198                         Raiders of the Lost Ark (1981)
# 2571                                     Matrix, The (1999)
# 318                        Shawshank Redemption, The (1994)
# 593                        Silence of the Lambs, The (1991)
# 2762                                Sixth Sense, The (1999)
#
#                                      genres    rating  views
# movie_id
# 2858                           Comedy|Drama  4.272414    580
# 260         Action|Adventure|Fantasy|Sci-Fi  4.451143    481
# 1196      Action|Adventure|Drama|Sci-Fi|War  4.325153    489
# 527                               Drama|War  4.552846    369
# 2028                       Action|Drama|War  4.405034    437
# 1198                       Action|Adventure  4.454545    407
# 2571                 Action|Sci-Fi|Thriller  4.361364    440
# 318                                   Drama  4.531609    348
# 593                          Drama|Thriller  4.330120    415
# 2762                               Thriller  4.394737    380

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
s = "Animation Children's Comedy"
tf_wrong = TfidfVectorizer(analyzer='word', ngram_range=(1,2))
tf_wrong.fit([s])
tf_wrong.get_feature_names()
# ['animation', 'animation children', 'children', 'children comedy', 'comedy']
# Out:
# ['animation', 'animation children', 'children', 'children comedy', 'comedy']

# %%
[c for i in range(1,2) for c in combinations(s.split(), r=i)]
# Out:
# [('Animation',), ("Children's",), ('Comedy',)]

# %%
tf = TfidfVectorizer(analyzer=lambda s: (c for i in range(1,4)
                                             for c in combinations(s.split('|'), r=i)))
tfidf_matrix = tf.fit_transform(movies['genres'])
tfidf_matrix.shape
# Out:
# (3883, 353)

# %%
pd.DataFrame(tfidf_matrix.todense(), columns=tf.get_feature_names(), index=movies.title).sample(5, axis=1).sample(10, axis=0)
# Out:
#                                          (Comedy, Drama, War)  \
# title
# Annie Hall (1977)                                         0.0
# Fast, Cheap & Out of Control (1997)                       0.0
# Dances with Wolves (1990)                                 0.0
# Blood Simple (1984)                                       0.0
# Commitments, The (1991)                                   0.0
# Harriet the Spy (1996)                                    0.0
# Quatermass II (1957)                                      0.0
# I Love You, I Love You Not (1996)                         0.0
# Never Talk to Strangers (1995)                            0.0
# Free Willy 2: The Adventure Home (1995)                   0.0
#
#                                          (Action, Romance, War)  \
# title
# Annie Hall (1977)                                           0.0
# Fast, Cheap & Out of Control (1997)                         0.0
# Dances with Wolves (1990)                                   0.0
# Blood Simple (1984)                                         0.0
# Commitments, The (1991)                                     0.0
# Harriet the Spy (1996)                                      0.0
# Quatermass II (1957)                                        0.0
# I Love You, I Love You Not (1996)                           0.0
# Never Talk to Strangers (1995)                              0.0
# Free Willy 2: The Adventure Home (1995)                     0.0
#
#                                          (Adventure, Comedy, War)  \
# title
# Annie Hall (1977)                                             0.0
# Fast, Cheap & Out of Control (1997)                           0.0
# Dances with Wolves (1990)                                     0.0
# Blood Simple (1984)                                           0.0
# Commitments, The (1991)                                       0.0
# Harriet the Spy (1996)                                        0.0
# Quatermass II (1957)                                          0.0
# I Love You, I Love You Not (1996)                             0.0
# Never Talk to Strangers (1995)                                0.0
# Free Willy 2: The Adventure Home (1995)                       0.0
#
#                                          (Action, Children's, Fantasy)  \
# title
# Annie Hall (1977)                                                  0.0
# Fast, Cheap & Out of Control (1997)                                0.0
# Dances with Wolves (1990)                                          0.0
# Blood Simple (1984)                                                0.0
# Commitments, The (1991)                                            0.0
# Harriet the Spy (1996)                                             0.0
# Quatermass II (1957)                                               0.0
# I Love You, I Love You Not (1996)                                  0.0
# Never Talk to Strangers (1995)                                     0.0
# Free Willy 2: The Adventure Home (1995)                            0.0
#
#                                          (Animation, Children's, Thriller)
# title
# Annie Hall (1977)                                                      0.0
# Fast, Cheap & Out of Control (1997)                                    0.0
# Dances with Wolves (1990)                                              0.0
# Blood Simple (1984)                                                    0.0
# Commitments, The (1991)                                                0.0
# Harriet the Spy (1996)                                                 0.0
# Quatermass II (1957)                                                   0.0
# I Love You, I Love You Not (1996)                                      0.0
# Never Talk to Strangers (1995)                                         0.0
# Free Willy 2: The Adventure Home (1995)                                0.0

# %%
from sklearn.metrics.pairwise import cosine_similarity
cosine_sim = cosine_similarity(tfidf_matrix)

# %%
cosine_sim_df = pd.DataFrame(cosine_sim, index=movies['title'], columns=movies['title'])
print('Shape:', cosine_sim_df.shape)
cosine_sim_df.sample(5, axis=1).round(2)
# Out:
# Shape: (3883, 3883)
# title                               Night on Earth (1991)  \
# title
# Toy Story (1995)                                     0.08
# Jumanji (1995)                                       0.00
# Grumpier Old Men (1995)                              0.18
# Waiting to Exhale (1995)                             1.00
# Father of the Bride Part II (1995)                   0.45
# ...                                                   ...
# Meet the Parents (2000)                              0.45
# Requiem for a Dream (2000)                           0.39
# Tigerland (2000)                                     0.39
# Two Family House (2000)                              0.39
# Contender, The (2000)                                0.13
#
# title                               Cyrano de Bergerac (1990)  \
# title
# Toy Story (1995)                                         0.00
# Jumanji (1995)                                           0.00
# Grumpier Old Men (1995)                                  0.15
# Waiting to Exhale (1995)                                 0.06
# Father of the Bride Part II (1995)                       0.00
# ...                                                       ...
# Meet the Parents (2000)                                  0.00
# Requiem for a Dream (2000)                               0.16
# Tigerland (2000)                                         0.16
# Two Family House (2000)                                  0.16
# Contender, The (2000)                                    0.05
#
# title                               King Kong (1933)  \
# title
# Toy Story (1995)                                0.00
# Jumanji (1995)                                  0.07
# Grumpier Old Men (1995)                         0.00
# Waiting to Exhale (1995)                        0.00
# Father of the Bride Part II (1995)              0.00
# ...                                              ...
# Meet the Parents (2000)                         0.00
# Requiem for a Dream (2000)                      0.00
# Tigerland (2000)                                0.00
# Two Family House (2000)                         0.00
# Contender, The (2000)                           0.00
#
# title                               Crocodile Dundee II (1988)  \
# title
# Toy Story (1995)                                          0.05
# Jumanji (1995)                                            0.14
# Grumpier Old Men (1995)                                   0.13
# Waiting to Exhale (1995)                                  0.14
# Father of the Bride Part II (1995)                        0.32
# ...                                                        ...
# Meet the Parents (2000)                                   0.32
# Requiem for a Dream (2000)                                0.00
# Tigerland (2000)                                          0.00
# Two Family House (2000)                                   0.00
# Contender, The (2000)                                     0.00
#
# title                               Big Fella (1937)
# title
# Toy Story (1995)                                0.00
# Jumanji (1995)                                  0.00
# Grumpier Old Men (1995)                         0.00
# Waiting to Exhale (1995)                        0.09
# Father of the Bride Part II (1995)              0.00
# ...                                              ...
# Meet the Parents (2000)                         0.00
# Requiem for a Dream (2000)                      0.23
# Tigerland (2000)                                0.23
# Two Family House (2000)                         0.23
# Contender, The (2000)                           0.08
#
# [3883 rows x 5 columns]

# %%
def genre_recommendations(i, M, items, k=10):
    """
    Recommends movies based on a similarity dataframe

    Parameters
    ----------
    i : str
        Movie (index of the similarity dataframe)
    M : pd.DataFrame
        Similarity dataframe, symmetric, with movies as indices and columns
    items : pd.DataFrame
        Contains both the title and some other features used to define similarity
    k : int
        Amount of recommendations to return

    """
    ix = M.loc[:,i].to_numpy().argpartition(range(-1,-k,-1))
    closest = M.columns[ix[-1:-(k+2):-1]]
    closest = closest.drop(i, errors='ignore')
    return pd.DataFrame(closest).merge(items).head(k)

# %%
movies[movies.title.eq('2001: A Space Odyssey (1968)')]
# Out:
#      movie_id                         title                         genres
# 912       924  2001: A Space Odyssey (1968)  Drama|Mystery|Sci-Fi|Thriller

# %%
genre_recommendations('2001: A Space Odyssey (1968)', cosine_sim_df, movies[['title', 'genres']])
# Out:
#                                    title                          genres
# 0  X-Files: Fight the Future, The (1998)         Mystery|Sci-Fi|Thriller
# 1                     Client, The (1994)          Drama|Mystery|Thriller
# 2        Talented Mr. Ripley, The (1999)          Drama|Mystery|Thriller
# 3                       Communion (1989)           Drama|Sci-Fi|Thriller
# 4                         Gattaca (1997)           Drama|Sci-Fi|Thriller
# 5           Thirteenth Floor, The (1999)           Drama|Sci-Fi|Thriller
# 6                   Event Horizon (1997)  Action|Mystery|Sci-Fi|Thriller
# 7                            2010 (1984)                  Mystery|Sci-Fi
# 8                         Stalker (1979)                  Mystery|Sci-Fi
# 9                     Deep Impact (1998)    Action|Drama|Sci-Fi|Thriller
